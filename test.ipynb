# %%
import pandas as pd
import numpy as np

# %%
ed = pd.read_csv('electoral-democracy.csv')
latest_ed = ed[ed['Year']==2021].copy()
ed.head()
# Out:
#         Entity Code  Year  electdem_vdem_owid  electdem_vdem_high_owid  \
# 0  Afghanistan  AFG  1789               0.018                    0.026
# 1  Afghanistan  AFG  1790               0.018                    0.026
# 2  Afghanistan  AFG  1791               0.018                    0.026
# 3  Afghanistan  AFG  1792               0.018                    0.026
# 4  Afghanistan  AFG  1793               0.018                    0.026
#
#    electdem_vdem_low_owid
# 0                   0.012
# 1                   0.012
# 2                   0.012
# 3                   0.012
# 4                   0.012

# %%
import altair as alt

# %%
latest_ed
# Out:
#             Entity      Code  Year  electdem_vdem_owid  \
# 232    Afghanistan       AFG  2021            0.160000
# 465         Africa       NaN  2021            0.401357
# 573        Albania       ALB  2021            0.478000
# 695        Algeria       DZA  2021            0.284000
# 817         Angola       AGO  2021            0.351000
# ...            ...       ...   ...                 ...
# 31258        World  OWID_WRL  2021            0.505972
# 31548        Yemen       YEM  2021            0.112000
# 31750       Zambia       ZMB  2021            0.379000
# 31872     Zanzibar  OWID_ZAN  2021            0.263000
# 31994     Zimbabwe       ZWE  2021            0.281000
#
#        electdem_vdem_high_owid  electdem_vdem_low_owid
# 232                   0.171000                0.143000
# 465                   0.443054                0.358589
# 573                   0.539000                0.419000
# 695                   0.314000                0.252000
# ...

# %%
alt.Chart(latest_ed).mark_bar().encode(x='Entity', y='electdem_vdem_owid')
# Out:
# alt.Chart(...)
